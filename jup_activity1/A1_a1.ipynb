# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../csvExamples/courses.csv')

# %%
df.head(2)
# Out:
#   Programming Language  Number of Downloads  Learning Days
# 0           JavaScript                50000             45
# 1               Python                45000             30

# %%
plt.bar(df['Programming Language'],
                df['Learning Days'],
                color='blue')
# Out:
# <BarContainer object of 10 artists>

# %%
plt.xlabel('Programming Language')
# Out:
# Text(0.5, 0, 'Programming Language')

# %%
plt.ylabel('Days to Learn')
# Out:
# Text(0, 0.5, 'Days to Learn')

# %%
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.title('Days to Learn Programming Languages')
# Out:
# Text(0.5, 1.0, 'Days to Learn Programming Languages')

# %%
plt.show()
